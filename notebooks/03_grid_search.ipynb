# %%
import sys
from pathlib import Path

# Resolve project root (notebook is in notebooks/)
PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# Define data paths (relative to project root)
MUT_PATH = [
    "data/raw/mutations/filtered_mutations.bed",
]
FAI_PATH = "data/raw/reference/GRCh37.fa.fai"
FASTA_PATH = "data/raw/reference/GRCh37.fa"
TIMING_BW = "data/raw/timing/repliSeq_SknshWaveSignalRep1.bigWig"

DNASE_MAP_PATH = "data/raw/DNase-seq/celltype_dnase_map.json"

TUMOUR_FILTER = None

# %%
from scripts.grid_search.runner import run_grid_experiment

# Simple sanity check
simple_check = run_grid_experiment(
    mut_path=MUT_PATH,
    fai_path=FAI_PATH,
    fasta_path=FASTA_PATH,
    dnase_map_path=DNASE_MAP_PATH,
    timing_bigwig=TIMING_BW,
    per_sample_count=2,
    base_seed=123,
    track_strategies=["counts_raw", "exp_decay"],
    counts_raw_bins=[1000000],
    exp_decay_bins=[1000000],
    exp_decay_decay_bp_grid=[200000],
    exp_decay_max_distance_bp_grid=[1000000],
    covariate_sets=[["gc", "cpg", "timing"]],
    include_trinuc=False,
    downsample_counts=None,
    save_per_bin=False,
    out_dir="outputs/experiments/simple_check",
)
simple_check.head()
# Out:
# [00:33:40] INFO Session start
# [00:33:40] INFO Inputs
# [00:33:40] INFO   mutations_bed:       [PosixPath('/home/lem/projects/mut-epi-origin/data/raw/mutations/filtered_mutations.bed')]
# [00:33:40] INFO   fasta:               /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa
# [00:33:40] INFO   fai:                 /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa.fai
# [00:33:40] INFO   dnase_bigwigs:       myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [00:33:40] INFO   timing_bigwig:       /home/lem/projects/mut-epi-origin/data/raw/timing/repliSeq_SknshWaveSignalRep1.bigWig
# [00:33:40] INFO   tumour_filter:       AML,LAML,NKTL,BCC,LMS,ESAD,ESCA,NBL,GBM,LGG,SKCM,MELA
# [00:33:40] INFO Grid
# [00:33:40] INFO   chroms:              22
# [00:33:40] INFO   configs:             4
# [00:33:40] INFO START Sample selection (per-sample idx=0) ...
# [00:35:33] INFO DONE Sample selection (per-sample idx=0) (1m56.7s)
# [00:35:33] INFO   sample_slice:        0:1
# [00:35:33] INFO   selected_samples:    1
# [00:35:33] INFO   mutations_loaded:    311,346
# [00:35:33] INFO   downsample_target:   none
# [00:35:33] INFO config bin=1000000 track=counts_raw covs=gc-cpg-timing
# [00:35:33] INFO Run start  [1/4]
# [00:35:33] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [00:35:33] INFO   standardise:         per_chrom (on)
# [00:35:33] INFO   rf_seed:             10123
# [00:35:33] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [00:35:33] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [00:35:33] INFO   chrom  1/22  elapsed=0.0s  rate=1437.608 chr/s  eta=0.0s
# [00:36:47] INFO   chrom  5/22  elapsed=1m15.9s  rate=0.066 chr/s  eta=4m18.0s
# [00:38:05] INFO   chrom 10/22  elapsed=2m35.7s  rate=0.064 chr/s  eta=3m06.8s
# [00:39:10] INFO   chrom 15/22  elapsed=3m44.4s  rate=0.067 chr/s  eta=1m44.7s
# [00:40:04] INFO   chrom 20/22  elapsed=4m39.8s  rate=0.071 chr/s  eta=28.0s
# [00:40:22] INFO   chrom 22/22  elapsed=4m58.6s  rate=0.074 chr/s  eta=0.0s
# [00:40:31] INFO Run summary
# [00:40:31] INFO   bins_total:          2,897
# [00:40:31] INFO   mutations_total:     299,621
# [00:40:31] INFO   best (RF resid corr): mela  r=-0.2440  margin=0.0912
# [00:40:31] INFO   rf_r2_mean_weighted: 0.8142
# [00:40:31] INFO   ridge_r2_mean_weighted: 0.6214
# [00:40:31] INFO Outputs
# [00:40:31] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/config.json
# [00:40:31] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [00:40:31] INFO   per_bin:             skipped
# [00:40:31] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [00:40:31] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [00:40:31] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0 (307.9s)
# [00:40:31] INFO config bin=1000000 track=exp_decay covs=gc-cpg-timing
# [00:40:31] INFO Run start  [2/4]
# [00:40:31] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [00:40:31] INFO   standardise:         per_chrom (on)
# [00:40:31] INFO   rf_seed:             10123
# [00:40:31] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [00:40:31] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [00:40:31] INFO   chrom  1/22  elapsed=0.0s  rate=872.029 chr/s  eta=0.0s
# [00:41:43] INFO   chrom  5/22  elapsed=1m13.5s  rate=0.068 chr/s  eta=4m10.1s
# [00:42:56] INFO   chrom 10/22  elapsed=2m30.2s  rate=0.067 chr/s  eta=3m00.3s
# [00:44:01] INFO   chrom 15/22  elapsed=3m37.1s  rate=0.069 chr/s  eta=1m41.3s
# [00:44:54] INFO   chrom 20/22  elapsed=4m31.5s  rate=0.074 chr/s  eta=27.1s
# [00:45:13] INFO   chrom 22/22  elapsed=4m50.7s  rate=0.076 chr/s  eta=0.0s
# [00:45:22] INFO Run summary
# [00:45:22] INFO   bins_total:          2,897
# [00:45:22] INFO   mutations_total:     299,621
# [00:45:22] INFO   best (RF resid corr): mela  r=-0.2427  margin=0.0921
# [00:45:22] INFO   rf_r2_mean_weighted: 0.8062
# [00:45:22] INFO   ridge_r2_mean_weighted: 0.6016
# [00:45:22] INFO Outputs
# [00:45:22] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/config.json
# [00:45:22] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [00:45:22] INFO   per_bin:             skipped
# [00:45:22] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [00:45:22] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [00:45:22] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--DO222423__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0 (300.1s)
# [00:45:22] INFO START Sample selection (per-sample idx=1) ...
# [00:47:18] INFO DONE Sample selection (per-sample idx=1) (2m00.8s)
# [00:47:18] INFO   sample_slice:        1:2
# [00:47:18] INFO   selected_samples:    1
# [00:47:18] INFO   mutations_loaded:    10
# [00:47:18] INFO   downsample_target:   none
# [00:47:18] INFO config bin=1000000 track=counts_raw covs=gc-cpg-timing
# [00:47:18] INFO Run start  [3/4]
# [00:47:18] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [00:47:18] INFO   standardise:         per_chrom (on)
# [00:47:18] INFO   rf_seed:             10123
# [00:47:18] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [00:47:18] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [00:47:18] INFO   chrom  1/22  elapsed=0.0s  rate=851.109 chr/s  eta=0.0s
# [00:48:28] INFO   chrom  5/22  elapsed=1m11.4s  rate=0.070 chr/s  eta=4m02.9s
# [00:49:31] INFO   chrom 10/22  elapsed=2m17.0s  rate=0.073 chr/s  eta=2m44.4s
# [00:50:22] INFO   chrom 15/22  elapsed=3m09.0s  rate=0.079 chr/s  eta=1m28.2s
# [00:51:00] INFO   chrom 20/22  elapsed=3m48.7s  rate=0.087 chr/s  eta=22.9s
# [00:51:12] INFO   chrom 22/22  elapsed=4m01.1s  rate=0.091 chr/s  eta=0.0s
# [00:51:17] INFO Run summary
# [00:51:17] INFO   bins_total:          2,897
# [00:51:17] INFO   mutations_total:     10
# [00:51:17] INFO   best (RF resid corr): kera  r=0.0099  margin=0.0115
# [00:51:17] INFO   rf_r2_mean_weighted: 0.1998
# [00:51:17] INFO   ridge_r2_mean_weighted: 0.1050
# [00:51:17] INFO Outputs
# [00:51:17] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/config.json
# [00:51:17] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [00:51:17] INFO   per_bin:             skipped
# [00:51:17] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [00:51:17] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [00:51:17] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0 (247.0s)
# [00:51:17] INFO config bin=1000000 track=exp_decay covs=gc-cpg-timing
# [00:51:17] INFO Run start  [4/4]
# [00:51:17] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [00:51:17] INFO   standardise:         per_chrom (on)
# [00:51:17] INFO   rf_seed:             10123
# [00:51:17] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [00:51:17] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [00:51:17] INFO   chrom  1/22  elapsed=0.0s  rate=1094.287 chr/s  eta=0.0s
# [00:52:26] INFO   chrom  5/22  elapsed=1m10.3s  rate=0.071 chr/s  eta=3m59.1s
# [00:53:29] INFO   chrom 10/22  elapsed=2m15.0s  rate=0.074 chr/s  eta=2m42.0s
# [00:54:19] INFO   chrom 15/22  elapsed=3m06.1s  rate=0.081 chr/s  eta=1m26.9s
# [00:54:57] INFO   chrom 20/22  elapsed=3m45.8s  rate=0.089 chr/s  eta=22.6s
# [00:55:09] INFO   chrom 22/22  elapsed=3m57.5s  rate=0.093 chr/s  eta=0.0s
# [00:55:15] INFO Run summary
# [00:55:15] INFO   bins_total:          2,897
# [00:55:15] INFO   mutations_total:     10
# [00:55:15] INFO   best (RF resid corr): kera  r=0.0025  margin=0.0153
# [00:55:15] INFO   rf_r2_mean_weighted: 0.2266
# [00:55:15] INFO   ridge_r2_mean_weighted: 0.1047
# [00:55:15] INFO Outputs
# [00:55:15] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/config.json
# [00:55:15] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [00:55:15] INFO   per_bin:             skipped
# [00:55:15] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [00:55:15] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [00:55:15] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--DO46065__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0 (243.2s)
#    sample_size_k  repeat  seed_samples  n_selected_samples  \
# 0              1       0           123                   1
# 1              1       0           123                   1
# 2              1       0           123                   1
# 3              1       0           123                   1
#
#    sample_slice_start  sample_slice_end  sample_index  \
# 0                   0                 1             0
# 1                   0                 1             0
# 2                   1                 2             1
# 3                   1                 2             1
#
#                       sample_id                    sample_tag sample_mode  \
# 0  filtered_mutations::DO222423  filtered_mutations--DO222423  per_sample
# 1  filtered_mutations::DO222423  filtered_mutations--DO222423  per_sample
# 2   filtered_mutations::DO46065   filtered_mutations--DO46065  per_sample
# 3   filtered_mutations::DO46065   filtered_mutations--DO46065  per_sample
#
#    ... is_correct_rf_resid is_correct_local_score downsample_applied  \
# 0  ...                True                   True              False
# 1  ...                True                   True              False
# 2  ...               False                  False              False
# 3  ...               False                  False              False
#
#   downsample_ratio  rf_top_feature_perm  rf_top_feature_importance_perm  \
# 0              1.0           dnase_mela                        0.994482
# 1              1.0           dnase_mela                        0.966554
# 2              1.0          timing_mean                        0.128926
# 3              1.0          timing_mean                        0.069411
#
#   rf_top_is_dnase exp_decay_bin exp_decay_decay_bp  exp_decay_max_distance_bp
# 0            True           NaN                NaN                        NaN
# 1            True     1000000.0           200000.0                  1000000.0
# 2           False           NaN                NaN                        NaN
# 3           False     1000000.0           200000.0                  1000000.0
#
# [4 rows x 160 columns]
