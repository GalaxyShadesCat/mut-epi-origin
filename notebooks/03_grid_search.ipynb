# %%
import sys
from pathlib import Path

# Resolve project root (notebook is in notebooks/)
PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# Define data paths (relative to project root)
MUT_PATH = [
    "data/raw/mutations/filtered_mutations.bed",
]
FAI_PATH = "data/raw/reference/GRCh37.fa.fai"
FASTA_PATH = "data/raw/reference/GRCh37.fa"
TIMING_BW = "data/raw/timing/repliSeq_SknshWaveSignalRep1.bigWig"

DNASE_MAP_PATH = "data/raw/DNase-seq/celltype_dnase_map.json"

TUMOUR_FILTER = None

# %%
from scripts.grid_search.runner import run_grid_experiment

# Simple sanity check
simple_check = run_grid_experiment(
    mut_path=MUT_PATH,
    fai_path=FAI_PATH,
    fasta_path=FASTA_PATH,
    dnase_map_path=DNASE_MAP_PATH,
    timing_bigwig=TIMING_BW,
    per_sample_count=5,
    pearson_score_window_bins=1,
    pearson_score_smoothing="none",
    pearson_score_smooth_param=None,
    pearson_score_transform="none",
    pearson_score_zscore=False,
    pearson_score_weights=(0.7, 0.3),
    spearman_score_window_bins=5,
    spearman_score_smoothing="none",
    spearman_score_smooth_param=None,
    spearman_score_transform="none",
    spearman_score_zscore=False,
    spearman_score_weights=(0.7, 0.3),
    base_seed=123,
    track_strategies=["counts_raw", "exp_decay"],
    counts_raw_bins=[1000000],
    exp_decay_bins=[1000000],
    exp_decay_decay_bp_grid=[200000],
    exp_decay_max_distance_bp_grid=[1000000],
    covariate_sets=[["gc", "cpg", "timing"]],
    include_trinuc=False,
    downsample_counts=None,
    save_per_bin=False,
    out_dir="outputs/experiments/simple_check",
)
simple_check.head()
# Out:
# [18:26:46] INFO Session start
# [18:26:46] INFO Inputs
# [18:26:46] INFO   mutations_bed:       [PosixPath('/home/lem/projects/mut-epi-origin/data/raw/mutations/filtered_mutations.bed')]
# [18:26:46] INFO   fasta:               /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa
# [18:26:46] INFO   fai:                 /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa.fai
# [18:26:46] INFO   dnase_bigwigs:       myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [18:26:46] INFO   timing_bigwig:       /home/lem/projects/mut-epi-origin/data/raw/timing/repliSeq_SknshWaveSignalRep1.bigWig
# [18:26:46] INFO   tumour_filter:       AML,LAML,NKTL,BCC,LMS,ESAD,ESCA,NBL,GBM,LGG,SKCM,MELA
# [18:26:46] INFO Grid
# [18:26:46] INFO   chroms:              22
# [18:26:46] INFO   configs:             10
# [18:26:46] INFO START Sample selection (per-sample idx=0) ...
# [18:28:43] INFO DONE Sample selection (per-sample idx=0) (2m03.2s)
# [18:28:43] INFO   sample_slice:        0:1
# [18:28:43] INFO   selected_samples:    1
# [18:28:43] INFO   mutations_loaded:    5,440
# [18:28:43] INFO   downsample_target:   none
# [18:28:43] INFO config bin=1000000 track=counts_raw covs=gc-cpg-timing
# [18:28:43] INFO Run start  [1/10]
# [18:28:43] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [18:28:43] INFO   standardise:         per_chrom (on)
# [18:28:43] INFO   rf_seed:             10123
# [18:28:43] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [18:28:43] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [18:28:43] INFO   chrom  1/22  elapsed=0.0s  rate=686.634 chr/s  eta=0.0s
# [18:30:12] INFO   chrom  5/22  elapsed=1m33.7s  rate=0.053 chr/s  eta=5m18.5s
# [18:31:40] INFO   chrom 10/22  elapsed=3m05.6s  rate=0.054 chr/s  eta=3m42.7s
# [18:32:56] INFO   chrom 15/22  elapsed=4m24.8s  rate=0.057 chr/s  eta=2m03.6s
# [18:33:56] INFO   chrom 20/22  elapsed=5m28.1s  rate=0.061 chr/s  eta=32.8s
# [18:34:17] INFO   chrom 22/22  elapsed=5m50.2s  rate=0.063 chr/s  eta=0.0s
# [18:34:28] INFO Run summary
# [18:34:28] INFO   bins_total:          2,897
# [18:34:28] INFO   mutations_total:     5,278
# [18:34:28] INFO   correct_celltypes:   nkc
# [18:34:28] INFO   Pearson r pred=nkc  score=-0.2966
# [18:34:28] INFO   Pearson r (linear covariate) pred=myel_prog  score=-0.1989
# [18:34:28] INFO   Spearman r pred=nkc  score=-0.3070
# [18:34:28] INFO   Spearman r (linear covariate) pred=myel_prog  score=-0.2145
# [18:34:28] INFO   Local score (pearson, linear covariate) pred=nkc  score=-0.1758
# [18:34:28] INFO   Local score (spearman, linear covariate) pred=myel_prog  score=-0.1741
# [18:34:28] INFO   RF (non-linear covariate) pred=nkc  score=-0.1415
# [18:34:28] INFO Outputs
# [18:34:28] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/config.json
# [18:34:28] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [18:34:28] INFO   per_bin:             skipped
# [18:34:28] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [18:34:28] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [18:34:28] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0 (360.9s)
# [18:34:28] INFO config bin=1000000 track=exp_decay covs=gc-cpg-timing
# [18:34:28] INFO Run start  [2/10]
# [18:34:28] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [18:34:28] INFO   standardise:         per_chrom (on)
# [18:34:28] INFO   rf_seed:             10123
# [18:34:28] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [18:34:28] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [18:34:28] INFO   chrom  1/22  elapsed=0.0s  rate=1242.122 chr/s  eta=0.0s
# [18:35:50] INFO   chrom  5/22  elapsed=1m27.0s  rate=0.057 chr/s  eta=4m55.9s
# [18:37:17] INFO   chrom 10/22  elapsed=2m56.4s  rate=0.057 chr/s  eta=3m31.6s
# [18:38:30] INFO   chrom 15/22  elapsed=4m13.9s  rate=0.059 chr/s  eta=1m58.5s
# [18:39:29] INFO   chrom 20/22  elapsed=5m16.3s  rate=0.063 chr/s  eta=31.6s
# [18:39:51] INFO   chrom 22/22  elapsed=5m38.0s  rate=0.065 chr/s  eta=0.0s
# [18:40:00] INFO Run summary
# [18:40:00] INFO   bins_total:          2,897
# [18:40:00] INFO   mutations_total:     5,278
# [18:40:00] INFO   correct_celltypes:   nkc
# [18:40:00] INFO   Pearson r pred=nkc  score=-0.2735
# [18:40:00] INFO   Pearson r (linear covariate) pred=myel_prog  score=-0.1912
# [18:40:00] INFO   Spearman r pred=nkc  score=-0.2680
# [18:40:00] INFO   Spearman r (linear covariate) pred=nkc  score=-0.2139
# [18:40:00] INFO   Local score (pearson, linear covariate) pred=nkc  score=-0.1745
# [18:40:00] INFO   Local score (spearman, linear covariate) pred=myel_prog  score=-0.1720
# [18:40:00] INFO   RF (non-linear covariate) pred=nkc  score=-0.1362
# [18:40:00] INFO Outputs
# [18:40:00] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/config.json
# [18:40:00] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [18:40:00] INFO   per_bin:             skipped
# [18:40:00] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [18:40:00] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [18:40:00] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--TNKTL21__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0 (348.7s)
# [18:40:00] INFO START Sample selection (per-sample idx=1) ...
# [18:41:58] INFO DONE Sample selection (per-sample idx=1) (2m02.6s)
# [18:41:58] INFO   sample_slice:        1:2
# [18:41:58] INFO   selected_samples:    1
# [18:41:58] INFO   mutations_loaded:    48,763
# [18:41:58] INFO   downsample_target:   none
# [18:41:58] INFO config bin=1000000 track=counts_raw covs=gc-cpg-timing
# [18:41:58] INFO Run start  [3/10]
# [18:41:58] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [18:41:58] INFO   standardise:         per_chrom (on)
# [18:41:58] INFO   rf_seed:             10123
# [18:41:58] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [18:41:58] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [18:41:58] INFO   chrom  1/22  elapsed=0.0s  rate=794.907 chr/s  eta=0.0s
# [18:43:20] INFO   chrom  5/22  elapsed=1m26.3s  rate=0.058 chr/s  eta=4m53.4s
# [18:44:46] INFO   chrom 10/22  elapsed=2m56.2s  rate=0.057 chr/s  eta=3m31.4s
# [18:46:01] INFO   chrom 15/22  elapsed=4m15.1s  rate=0.059 chr/s  eta=1m59.0s
# [18:47:00] INFO   chrom 20/22  elapsed=5m17.2s  rate=0.063 chr/s  eta=31.7s
# [18:47:22] INFO   chrom 22/22  elapsed=5m38.9s  rate=0.065 chr/s  eta=0.0s
# [18:47:31] INFO Run summary
# [18:47:31] INFO   bins_total:          2,897
# [18:47:31] INFO   mutations_total:     48,763
# [18:47:31] INFO   correct_celltypes:   eso_epi
# [18:47:31] INFO   Pearson r pred=fibr  score=-0.4189
# [18:47:31] INFO   Pearson r (linear covariate) pred=eso_epi  score=-0.3130
# [18:47:31] INFO   Spearman r pred=nkc  score=-0.3743
# [18:47:31] INFO   Spearman r (linear covariate) pred=eso_epi  score=-0.3398
# [18:47:31] INFO   Local score (pearson, linear covariate) pred=eso_epi  score=-0.3310
# [18:47:31] INFO   Local score (spearman, linear covariate) pred=eso_epi  score=-0.3213
# [18:47:31] INFO   RF (non-linear covariate) pred=fibr  score=-0.1707
# [18:47:31] INFO Outputs
# [18:47:31] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/config.json
# [18:47:31] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [18:47:31] INFO   per_bin:             skipped
# [18:47:31] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [18:47:31] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [18:47:31] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0 (349.5s)
# [18:47:31] INFO config bin=1000000 track=exp_decay covs=gc-cpg-timing
# [18:47:31] INFO Run start  [4/10]
# [18:47:31] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [18:47:31] INFO   standardise:         per_chrom (on)
# [18:47:31] INFO   rf_seed:             10123
# [18:47:31] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [18:47:31] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [18:47:31] INFO   chrom  1/22  elapsed=0.0s  rate=846.145 chr/s  eta=0.0s
# [18:48:53] INFO   chrom  5/22  elapsed=1m27.1s  rate=0.057 chr/s  eta=4m56.2s
# [18:50:20] INFO   chrom 10/22  elapsed=2m57.0s  rate=0.057 chr/s  eta=3m32.4s
# [18:51:33] INFO   chrom 15/22  elapsed=4m14.4s  rate=0.059 chr/s  eta=1m58.7s
# [18:52:33] INFO   chrom 20/22  elapsed=5m17.1s  rate=0.063 chr/s  eta=31.7s
# [18:52:55] INFO   chrom 22/22  elapsed=5m39.0s  rate=0.065 chr/s  eta=0.0s
# [18:53:04] INFO Run summary
# [18:53:04] INFO   bins_total:          2,897
# [18:53:04] INFO   mutations_total:     48,763
# [18:53:04] INFO   correct_celltypes:   eso_epi
# [18:53:04] INFO   Pearson r pred=fibr  score=-0.4112
# [18:53:04] INFO   Pearson r (linear covariate) pred=eso_epi  score=-0.3093
# [18:53:04] INFO   Spearman r pred=eso_epi  score=-0.3610
# [18:53:04] INFO   Spearman r (linear covariate) pred=eso_epi  score=-0.3406
# [18:53:04] INFO   Local score (pearson, linear covariate) pred=eso_epi  score=-0.3225
# [18:53:04] INFO   Local score (spearman, linear covariate) pred=eso_epi  score=-0.3118
# [18:53:04] INFO   RF (non-linear covariate) pred=fibr  score=-0.1643
# [18:53:04] INFO Outputs
# [18:53:04] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/config.json
# [18:53:04] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [18:53:04] INFO   per_bin:             skipped
# [18:53:04] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [18:53:04] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [18:53:04] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--LP6005409-DNA_A03__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0 (349.6s)
# [18:53:04] INFO START Sample selection (per-sample idx=2) ...
# [18:55:03] INFO DONE Sample selection (per-sample idx=2) (2m03.7s)
# [18:55:03] INFO   sample_slice:        2:3
# [18:55:03] INFO   selected_samples:    1
# [18:55:03] INFO   mutations_loaded:    1,231
# [18:55:03] INFO   downsample_target:   none
# [18:55:03] INFO config bin=1000000 track=counts_raw covs=gc-cpg-timing
# [18:55:03] INFO Run start  [5/10]
# [18:55:03] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [18:55:03] INFO   standardise:         per_chrom (on)
# [18:55:03] INFO   rf_seed:             10123
# [18:55:03] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [18:55:03] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [18:55:03] INFO   chrom  1/22  elapsed=0.0s  rate=534.857 chr/s  eta=0.0s
# [18:56:25] INFO   chrom  5/22  elapsed=1m26.5s  rate=0.058 chr/s  eta=4m54.1s
# [18:57:50] INFO   chrom 10/22  elapsed=2m55.9s  rate=0.057 chr/s  eta=3m31.0s
# [18:59:04] INFO   chrom 15/22  elapsed=4m13.6s  rate=0.059 chr/s  eta=1m58.3s
# [19:00:04] INFO   chrom 20/22  elapsed=5m16.4s  rate=0.063 chr/s  eta=31.6s
# [19:00:24] INFO   chrom 22/22  elapsed=5m38.2s  rate=0.065 chr/s  eta=0.0s
# [19:00:35] INFO Run summary
# [19:00:35] INFO   bins_total:          2,897
# [19:00:35] INFO   mutations_total:     1,140
# [19:00:35] INFO   correct_celltypes:   smc
# [19:00:35] INFO   Pearson r pred=fibr  score=-0.0398
# [19:00:35] INFO   Pearson r (linear covariate) pred=fibr  score=-0.0683
# [19:00:35] INFO   Spearman r pred=fibr  score=-0.0289
# [19:00:35] INFO   Spearman r (linear covariate) pred=astro_hippo  score=-0.0738
# [19:00:35] INFO   Local score (pearson, linear covariate) pred=mela  score=-0.0623
# [19:00:35] INFO   Local score (spearman, linear covariate) pred=astro_hippo  score=-0.0755
# [19:00:35] INFO   RF (non-linear covariate) pred=fibr  score=-0.0389
# [19:00:35] INFO Outputs
# [19:00:35] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/config.json
# [19:00:35] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [19:00:35] INFO   per_bin:             skipped
# [19:00:35] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [19:00:35] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [19:00:35] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0 (348.8s)
# [19:00:35] INFO config bin=1000000 track=exp_decay covs=gc-cpg-timing
# [19:00:35] INFO Run start  [6/10]
# [19:00:35] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:00:35] INFO   standardise:         per_chrom (on)
# [19:00:35] INFO   rf_seed:             10123
# [19:00:35] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:00:35] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [19:00:35] INFO   chrom  1/22  elapsed=0.0s  rate=738.821 chr/s  eta=0.0s
# [19:01:57] INFO   chrom  5/22  elapsed=1m27.1s  rate=0.057 chr/s  eta=4m56.0s
# [19:03:23] INFO   chrom 10/22  elapsed=2m57.2s  rate=0.056 chr/s  eta=3m32.6s
# [19:04:38] INFO   chrom 15/22  elapsed=4m15.0s  rate=0.059 chr/s  eta=1m59.0s
# [19:05:37] INFO   chrom 20/22  elapsed=5m17.5s  rate=0.063 chr/s  eta=31.7s
# [19:05:57] INFO   chrom 22/22  elapsed=5m39.3s  rate=0.065 chr/s  eta=0.0s
# [19:06:08] INFO Run summary
# [19:06:08] INFO   bins_total:          2,897
# [19:06:08] INFO   mutations_total:     1,140
# [19:06:08] INFO   correct_celltypes:   smc
# [19:06:08] INFO   Pearson r pred=fibr  score=-0.0414
# [19:06:08] INFO   Pearson r (linear covariate) pred=fibr  score=-0.0667
# [19:06:08] INFO   Spearman r pred=fibr  score=-0.0139
# [19:06:08] INFO   Spearman r (linear covariate) pred=astro_hippo  score=-0.0699
# [19:06:08] INFO   Local score (pearson, linear covariate) pred=mela  score=-0.0634
# [19:06:08] INFO   Local score (spearman, linear covariate) pred=myel_prog  score=-0.0686
# [19:06:08] INFO   RF (non-linear covariate) pred=fibr  score=-0.0478
# [19:06:08] INFO Outputs
# [19:06:08] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/config.json
# [19:06:08] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [19:06:08] INFO   per_bin:             skipped
# [19:06:08] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [19:06:08] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:06:08] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--LMS31T1__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0 (349.9s)
# [19:06:08] INFO START Sample selection (per-sample idx=3) ...
# [19:08:05] INFO DONE Sample selection (per-sample idx=3) (2m02.7s)
# [19:08:05] INFO   sample_slice:        3:4
# [19:08:05] INFO   selected_samples:    1
# [19:08:05] INFO   mutations_loaded:    11,970
# [19:08:05] INFO   downsample_target:   none
# [19:08:05] INFO config bin=1000000 track=counts_raw covs=gc-cpg-timing
# [19:08:05] INFO Run start  [7/10]
# [19:08:05] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [19:08:05] INFO   standardise:         per_chrom (on)
# [19:08:05] INFO   rf_seed:             10123
# [19:08:05] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [19:08:05] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [19:08:05] INFO   chrom  1/22  elapsed=0.0s  rate=1574.344 chr/s  eta=0.0s
# [19:09:33] INFO   chrom  5/22  elapsed=1m33.5s  rate=0.053 chr/s  eta=5m17.9s
# [19:11:00] INFO   chrom 10/22  elapsed=3m03.6s  rate=0.054 chr/s  eta=3m40.3s
# [19:12:14] INFO   chrom 15/22  elapsed=4m21.7s  rate=0.057 chr/s  eta=2m02.1s
# [19:13:13] INFO   chrom 20/22  elapsed=5m24.3s  rate=0.062 chr/s  eta=32.4s
# [19:13:35] INFO   chrom 22/22  elapsed=5m46.0s  rate=0.064 chr/s  eta=0.0s
# [19:13:44] INFO Run summary
# [19:13:44] INFO   bins_total:          2,897
# [19:13:44] INFO   mutations_total:     11,970
# [19:13:44] INFO   correct_celltypes:   eso_epi
# [19:13:44] INFO   Pearson r pred=fibr  score=-0.3616
# [19:13:44] INFO   Pearson r (linear covariate) pred=eso_epi  score=-0.2471
# [19:13:44] INFO   Spearman r pred=nkc  score=-0.3206
# [19:13:44] INFO   Spearman r (linear covariate) pred=eso_epi  score=-0.2674
# [19:13:44] INFO   Local score (pearson, linear covariate) pred=eso_epi  score=-0.1985
# [19:13:44] INFO   Local score (spearman, linear covariate) pred=eso_epi  score=-0.2162
# [19:13:44] INFO   RF (non-linear covariate) pred=fibr  score=-0.1400
# [19:13:44] INFO Outputs
# [19:13:44] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/config.json
# [19:13:44] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [19:13:44] INFO   per_bin:             skipped
# [19:13:44] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [19:13:44] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [19:13:44] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0 (357.0s)
# [19:13:44] INFO config bin=1000000 track=exp_decay covs=gc-cpg-timing
# [19:13:44] INFO Run start  [8/10]
# [19:13:44] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:13:44] INFO   standardise:         per_chrom (on)
# [19:13:44] INFO   rf_seed:             10123
# [19:13:44] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:13:44] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [19:13:44] INFO   chrom  1/22  elapsed=0.0s  rate=1164.778 chr/s  eta=0.0s
# [19:15:08] INFO   chrom  5/22  elapsed=1m26.9s  rate=0.058 chr/s  eta=4m55.4s
# [19:16:33] INFO   chrom 10/22  elapsed=2m56.4s  rate=0.057 chr/s  eta=3m31.7s
# [19:17:47] INFO   chrom 15/22  elapsed=4m13.3s  rate=0.059 chr/s  eta=1m58.2s
# [19:18:45] INFO   chrom 20/22  elapsed=5m14.8s  rate=0.064 chr/s  eta=31.5s
# [19:19:09] INFO   chrom 22/22  elapsed=5m40.2s  rate=0.065 chr/s  eta=0.0s
# [19:19:20] INFO Run summary
# [19:19:20] INFO   bins_total:          2,897
# [19:19:20] INFO   mutations_total:     11,970
# [19:19:20] INFO   correct_celltypes:   eso_epi
# [19:19:20] INFO   Pearson r pred=fibr  score=-0.3395
# [19:19:20] INFO   Pearson r (linear covariate) pred=eso_epi  score=-0.2323
# [19:19:20] INFO   Spearman r pred=nkc  score=-0.2918
# [19:19:20] INFO   Spearman r (linear covariate) pred=eso_epi  score=-0.2476
# [19:19:20] INFO   Local score (pearson, linear covariate) pred=eso_epi  score=-0.1692
# [19:19:20] INFO   Local score (spearman, linear covariate) pred=eso_epi  score=-0.2004
# [19:19:20] INFO   RF (non-linear covariate) pred=fibr  score=-0.1307
# [19:19:20] INFO Outputs
# [19:19:20] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/config.json
# [19:19:20] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [19:19:20] INFO   per_bin:             skipped
# [19:19:20] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [19:19:20] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:19:20] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--LP6007514-DNA_A01__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0 (352.9s)
# [19:19:20] INFO START Sample selection (per-sample idx=4) ...
# [19:21:25] INFO DONE Sample selection (per-sample idx=4) (2m09.6s)
# [19:21:25] INFO   sample_slice:        4:5
# [19:21:25] INFO   selected_samples:    1
# [19:21:25] INFO   mutations_loaded:    12,878
# [19:21:25] INFO   downsample_target:   none
# [19:21:25] INFO config bin=1000000 track=counts_raw covs=gc-cpg-timing
# [19:21:25] INFO Run start  [9/10]
# [19:21:25] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [19:21:25] INFO   standardise:         per_chrom (on)
# [19:21:25] INFO   rf_seed:             10123
# [19:21:25] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [19:21:25] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [19:21:25] INFO   chrom  1/22  elapsed=0.0s  rate=446.987 chr/s  eta=0.0s
# [19:22:43] INFO   chrom  5/22  elapsed=1m23.4s  rate=0.060 chr/s  eta=4m43.6s
# [19:24:07] INFO   chrom 10/22  elapsed=2m52.0s  rate=0.058 chr/s  eta=3m26.4s
# [19:25:23] INFO   chrom 15/22  elapsed=4m10.8s  rate=0.060 chr/s  eta=1m57.1s
# [19:26:21] INFO   chrom 20/22  elapsed=5m12.1s  rate=0.064 chr/s  eta=31.2s
# [19:26:41] INFO   chrom 22/22  elapsed=5m33.5s  rate=0.066 chr/s  eta=0.0s
# [19:26:51] INFO Run summary
# [19:26:51] INFO   bins_total:          2,897
# [19:26:51] INFO   mutations_total:     11,992
# [19:26:51] INFO   correct_celltypes:   mela
# [19:26:51] INFO   Pearson r pred=mela  score=-0.3547
# [19:26:51] INFO   Pearson r (linear covariate) pred=mela  score=-0.2985
# [19:26:51] INFO   Spearman r pred=mela  score=-0.3332
# [19:26:51] INFO   Spearman r (linear covariate) pred=mela  score=-0.3171
# [19:26:51] INFO   Local score (pearson, linear covariate) pred=mela  score=-0.3517
# [19:26:51] INFO   Local score (spearman, linear covariate) pred=mela  score=-0.3207
# [19:26:51] INFO   RF (non-linear covariate) pred=mela  score=-0.1708
# [19:26:51] INFO Outputs
# [19:26:51] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/config.json
# [19:26:51] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [19:26:51] INFO   per_bin:             skipped
# [19:26:51] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [19:26:51] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0
# [19:26:51] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__counts_raw_bin=1000000__track=counts_raw__covs=gc-cpg-timing__tri=0 (343.9s)
# [19:26:51] INFO config bin=1000000 track=exp_decay covs=gc-cpg-timing
# [19:26:51] INFO Run start  [10/10]
# [19:26:51] INFO   id:                  k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:26:51] INFO   standardise:         per_chrom (on)
# [19:26:51] INFO   rf_seed:             10123
# [19:26:51] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:26:51] INFO   celltypes:           myel_prog, nkc, kera, smc, eso_epi, neuro_stem, astro_hippo, astro_spinal, mela, fibr
# [19:26:51] INFO   chrom  1/22  elapsed=0.0s  rate=1237.996 chr/s  eta=0.0s
# [19:28:11] INFO   chrom  5/22  elapsed=1m24.7s  rate=0.059 chr/s  eta=4m48.0s
# [19:29:37] INFO   chrom 10/22  elapsed=2m53.6s  rate=0.058 chr/s  eta=3m28.3s
# [19:30:49] INFO   chrom 15/22  elapsed=4m10.8s  rate=0.060 chr/s  eta=1m57.1s
# [19:31:47] INFO   chrom 20/22  elapsed=5m12.3s  rate=0.064 chr/s  eta=31.2s
# [19:32:09] INFO   chrom 22/22  elapsed=5m33.6s  rate=0.066 chr/s  eta=0.0s
# [19:32:17] INFO Run summary
# [19:32:17] INFO   bins_total:          2,897
# [19:32:17] INFO   mutations_total:     11,992
# [19:32:17] INFO   correct_celltypes:   mela
# [19:32:17] INFO   Pearson r pred=mela  score=-0.3381
# [19:32:17] INFO   Pearson r (linear covariate) pred=mela  score=-0.2778
# [19:32:17] INFO   Spearman r pred=mela  score=-0.2998
# [19:32:17] INFO   Spearman r (linear covariate) pred=mela  score=-0.2955
# [19:32:17] INFO   Local score (pearson, linear covariate) pred=mela  score=-0.3301
# [19:32:17] INFO   Local score (spearman, linear covariate) pred=mela  score=-0.2998
# [19:32:17] INFO   RF (non-linear covariate) pred=mela  score=-0.1594
# [19:32:17] INFO Outputs
# [19:32:17] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/config.json
# [19:32:17] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0/chrom_summary.csv
# [19:32:17] INFO   per_bin:             skipped
# [19:32:17] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/results.csv
# [19:32:17] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/simple_check/runs/k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0
# [19:32:17] INFO Run end k=1__rep=0__seed=123__sample=filtered_mutations--EXTERN-MELA-20140924-016__ds=none__exp_decay_bin=1000000__track=exp_decay__decay=200000_md=1000000__u=bp__covs=gc-cpg-timing__tri=0 (344.0s)
#    sample_size_k  repeat  seed_samples  n_selected_samples  \
# 0              1       0           123                   1
# 1              1       0           123                   1
# 2              1       0           123                   1
# 3              1       0           123                   1
# 4              1       0           123                   1
#
#    sample_slice_start  sample_slice_end  sample_index  \
# 0                   0                 1             0
# 1                   0                 1             0
# 2                   1                 2             1
# 3                   1                 2             1
# 4                   2                 3             2
#
#                                sample_id  \
# 0            filtered_mutations::TNKTL21
# 1            filtered_mutations::TNKTL21
# 2  filtered_mutations::LP6005409-DNA_A03
# 3  filtered_mutations::LP6005409-DNA_A03
# 4            filtered_mutations::LMS31T1
#
#                               sample_tag sample_mode  ...  \
# 0            filtered_mutations--TNKTL21  per_sample  ...
# 1            filtered_mutations--TNKTL21  per_sample  ...
# 2  filtered_mutations--LP6005409-DNA_A03  per_sample  ...
# 3  filtered_mutations--LP6005409-DNA_A03  per_sample  ...
# 4            filtered_mutations--LMS31T1  per_sample  ...
#
#   is_correct_pearson_local_score is_correct_spearman_local_score  \
# 0                           True                           False
# 1                           True                           False
# 2                           True                            True
# 3                           True                            True
# 4                          False                           False
#
#   downsample_applied downsample_ratio  rf_top_feature_perm  \
# 0              False              1.0            dnase_nkc
# 1              False              1.0            dnase_nkc
# 2              False              1.0            dnase_nkc
# 3              False              1.0            dnase_nkc
# 4              False              1.0          timing_mean
#
#    rf_top_feature_importance_perm rf_top_is_dnase exp_decay_bin  \
# 0                        0.383942            True           NaN
# 1                        0.316390            True     1000000.0
# 2                        0.170635            True           NaN
# 3                        0.149644            True     1000000.0
# 4                        0.079408           False           NaN
#
#   exp_decay_decay_bp  exp_decay_max_distance_bp
# 0                NaN                        NaN
# 1           200000.0                  1000000.0
# 2                NaN                        NaN
# 3           200000.0                  1000000.0
# 4                NaN                        NaN
#
# [5 rows x 255 columns]
