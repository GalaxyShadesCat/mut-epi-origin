# %%
import sys
from pathlib import Path

# Resolve project root (notebook is in analysis/)
PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# Define data paths
MUT_PATH = [
    PROJECT_ROOT / "data" / "raw" / "mutations" / "UV_mutations.bed",
    PROJECT_ROOT / "data" / "raw" / "mutations" / "ICGC_WGS_Feb20_mutations.MELA_SKCM.bed"
]
FAI_PATH = PROJECT_ROOT / "data" / "raw" / "reference" / "GRCh37.fa.fai"
FASTA_PATH = PROJECT_ROOT / "data" / "raw" / "reference" / "GRCh37.fa"
TIMING_BW = PROJECT_ROOT / "data" / "raw" / "timing" / "repliSeq_SknshWaveSignalRep1.bigWig"

DNASE_MAP = {
    "mela": PROJECT_ROOT / "data" / "raw" / "DNase-seq" / "mela_ENCFF285GEW.bigWig",
    "kera": PROJECT_ROOT / "data" / "raw" / "DNase-seq" / "kera_ENCFF597YXQ.bigWig",
    "fibr": PROJECT_ROOT / "data" / "raw" / "DNase-seq" / "fibr_ENCFF355OPU.bigWig",
}

# TUMOUR_WHITELIST = [
#     "MELA",
#     "SKCM",
# ]
TUMOUR_WHITELIST = None

# %%
from scripts.pipeline_mut_vs_accessibility import run_grid_experiment

# Small, fast smoke test
quick_results_1 = run_grid_experiment(
    mut_path=MUT_PATH,
    fai_path=FAI_PATH,
    fasta_path=FASTA_PATH,
    dnase_bigwigs=DNASE_MAP,
    timing_bigwig=TIMING_BW,
    sample_sizes=[5],
    repeats=1,
    base_seed=123,
    bin_sizes=[100_000],
    track_strategies=["counts_raw"],
    covariate_sets=[
        ["gc", "cpg"],
    ],
    include_trinuc=False,
    chroms=None,  # all chromosomes in the .fai
    standardise_tracks=True,
    standardise_scope="per_chrom",
    verbose=True,
    out_dir=PROJECT_ROOT / "outputs" / "experiments" / "mut_vs_dnase_quickcheck_v1",
    tumour_whitelist=TUMOUR_WHITELIST,
    save_per_bin=False,
)

quick_results_1.sort_values("best_celltype_linear_resid_value").head(5)
# Out:
# [13:56:33] INFO Session start
# [13:56:33] INFO Inputs
# [13:56:33] INFO   mutations_bed:       /home/lem/projects/mut-epi-origin/data/raw/mutations/UV_mutations.bed
# [13:56:33] INFO   fasta:               /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa
# [13:56:33] INFO   fai:                 /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa.fai
# [13:56:33] INFO   dnase_bigwigs:       mela, kera, fibr
# [13:56:33] INFO   timing_bigwig:       /home/lem/projects/mut-epi-origin/data/raw/timing/repliSeq_SknshWaveSignalRep1.bigWig
# [13:56:33] INFO Grid
# [13:56:33] INFO   chroms:              24
# [13:56:33] INFO   configs:             1
# [13:56:33] INFO START Sample selection (k=5, rep=0, seed=123) ...
# [13:56:38] INFO DONE Sample selection (k=5, rep=0, seed=123) (5.5s)
# [13:56:38] INFO   selected_samples:    5
# [13:56:38] INFO   mutations_loaded:    431,607
# [13:56:38] INFO config bin=100000 track=counts_raw covs=gc-cpg
# [13:56:38] INFO Run start  [1/1]
# [13:56:38] INFO   id:                  k=5 rep=0 seed=123 bin=100000 track=counts raw covs=gc-cpg tri=0
# [13:56:38] INFO   standardise:         per_chrom (on)
# [13:56:38] INFO   rf_seed:             10123
# [13:56:38] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v1/runs/k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0
# [13:56:38] INFO   celltypes:           mela, kera, fibr
# [13:56:38] INFO   chrom  1/24  elapsed=0.0s  rate=536.980 chr/s  eta=0.0s
# [13:58:02] INFO   chrom  5/24  elapsed=1m25.5s  rate=0.058 chr/s  eta=5m25.0s
# [13:59:27] INFO   chrom 10/24  elapsed=2m52.5s  rate=0.058 chr/s  eta=4m01.5s
# [14:00:53] INFO   chrom 15/24  elapsed=4m19.8s  rate=0.058 chr/s  eta=2m35.9s
# [14:01:55] INFO   chrom 20/24  elapsed=5m22.1s  rate=0.062 chr/s  eta=1m04.4s
# [14:02:42] INFO   chrom 24/24  elapsed=6m10.9s  rate=0.065 chr/s  eta=0.0s
# [14:02:54] INFO Run summary
# [14:02:54] INFO   bins_total:          30,970
# [14:02:54] INFO   mutations_total:     431,607
# [14:02:54] INFO   best (RF resid corr): mela  r=-0.2340  margin=0.0651
# [14:02:54] INFO   rf_r2_mean_weighted: 0.7940
# [14:02:54] INFO   ridge_r2_mean_weighted: 0.3117
# [14:02:54] INFO Outputs
# [14:02:54] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v1/runs/k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0/config.json
# [14:02:54] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v1/runs/k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0/chrom_summary.csv
# [14:02:54] INFO   per_bin:             skipped
# [14:02:54] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v1/results.csv
# [14:02:54] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v1/runs/k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0
# [14:02:54] INFO Run end k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0 (382.4s)
#    sample_size_k  repeat  seed_samples  n_selected_samples  bin_size  \
# 0              5       0           123                   5    100000
#
#   track_strategy covariates  include_trinuc  n_mutations_total  n_bins_total  \
# 0     counts_raw     gc,cpg           False             431607         30970
#
#    ... best_celltype_rf_resid  best_celltype_rf_resid_value  \
# 0  ...                   mela                     -0.234003
#
#    best_minus_second_rf_resid  \
# 0                    0.065063
#
#                        rf_perm_importances_mean_json  \
# 0  {"gc_fraction": 0.23695488005873663, "cpg_per_...
#
#                       rf_feature_sign_corr_mean_json  \
# 0  {"gc_fraction": 0.12515185708863016, "cpg_per_...
#
#                                 ridge_coef_mean_json  rf_r2_mean_weighted  \
# 0  {"gc_fraction": 0.5994251551438511, "cpg_per_b...             0.793983
#
#    ridge_r2_mean_weighted  rf_top_celltype_feature_perm  \
# 0                0.311728                          mela
#
#    rf_top_celltype_importance_perm
# 0                         0.989604
#
# [1 rows x 45 columns]

# %%
from scripts.pipeline_mut_vs_accessibility import run_grid_experiment

# Quick-but-slightly-larger search (6 runs)
quick_results_2 = run_grid_experiment(
    mut_path=MUT_PATH,
    fai_path=FAI_PATH,
    fasta_path=FASTA_PATH,
    dnase_bigwigs=DNASE_MAP,
    timing_bigwig=TIMING_BW,
    sample_sizes=[5, 10],  # 2
    repeats=1,  # 1
    base_seed=123,
    bin_sizes=[100_000],  # 1
    track_strategies=["counts_raw", "counts_gauss", "inv_dist_gauss"],  # 3
    covariate_sets=[
        ["gc", "cpg"],  # 1
    ],
    include_trinuc=False,
    chroms=None,  # all chromosomes in the .fai
    standardise_tracks=True,
    standardise_scope="per_chrom",
    verbose=True,
    out_dir=PROJECT_ROOT / "outputs" / "experiments" / "mut_vs_dnase_quickcheck_v2",
    tumour_whitelist=TUMOUR_WHITELIST,
    save_per_bin=False,
)

quick_results_2.sort_values("best_celltype_linear_resid_value").head(10)
# Out:
# [15:26:48] INFO Session start
# [15:26:48] INFO Inputs
# [15:26:48] INFO   mutations_bed:       [PosixPath('/home/lem/projects/mut-epi-origin/data/raw/mutations/UV_mutations.bed'), PosixPath('/home/lem/projects/mut-epi-origin/data/raw/mutations/ICGC_WGS_Feb20_mutations.MELA_SKCM.bed')]
# [15:26:48] INFO   fasta:               /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa
# [15:26:48] INFO   fai:                 /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa.fai
# [15:26:48] INFO   dnase_bigwigs:       mela, kera, fibr
# [15:26:48] INFO   timing_bigwig:       /home/lem/projects/mut-epi-origin/data/raw/timing/repliSeq_SknshWaveSignalRep1.bigWig
# [15:26:48] INFO   tumour_whitelist:    none
# [15:26:48] INFO Grid
# [15:26:48] INFO   chroms:              24
# [15:26:48] INFO   configs:             6
# [15:26:48] INFO START Sample selection (k=5, rep=0, seed=123) ...
# [15:27:59] INFO DONE Sample selection (k=5, rep=0, seed=123) (1m12.3s)
# [15:27:59] INFO   selected_samples:    5
# [15:27:59] INFO   mutations_loaded:    870,228
# [15:27:59] INFO config bin=100000 track=counts_raw covs=gc-cpg
# [15:27:59] INFO Run start  [1/6]
# [15:27:59] INFO   id:                  k=5 rep=0 seed=123 bin=100000 track=counts raw covs=gc-cpg tri=0
# [15:27:59] INFO   standardise:         per_chrom (on)
# [15:27:59] INFO   rf_seed:             10123
# [15:27:59] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0
# [15:27:59] INFO   celltypes:           mela, kera, fibr
# [15:27:59] INFO   chrom  1/24  elapsed=0.0s  rate=530.169 chr/s  eta=0.0s
# [15:29:25] INFO   chrom  5/24  elapsed=1m28.6s  rate=0.056 chr/s  eta=5m36.5s
# [15:30:52] INFO   chrom 10/24  elapsed=2m57.7s  rate=0.056 chr/s  eta=4m08.7s
# [15:32:03] INFO   chrom 15/24  elapsed=4m09.7s  rate=0.060 chr/s  eta=2m29.8s
# [15:33:04] INFO   chrom 20/24  elapsed=5m12.3s  rate=0.064 chr/s  eta=1m02.5s
# [15:33:47] INFO   chrom 24/24  elapsed=5m56.7s  rate=0.067 chr/s  eta=0.0s
# [15:33:58] INFO Run summary
# [15:33:58] INFO   bins_total:          30,970
# [15:33:58] INFO   mutations_total:     870,228
# [15:33:58] INFO   best (RF resid corr): mela  r=-0.2304  margin=0.0585
# [15:33:58] INFO   rf_r2_mean_weighted: 0.8108
# [15:33:58] INFO   ridge_r2_mean_weighted: 0.3359
# [15:33:58] INFO Outputs
# [15:33:58] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0/config.json
# [15:33:58] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0/chrom_summary.csv
# [15:33:58] INFO   per_bin:             skipped
# [15:33:58] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/results.csv
# [15:33:58] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0
# [15:33:58] INFO Run end k=5_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0 (368.5s)
# [15:33:58] INFO config bin=100000 track=counts_gauss covs=gc-cpg
# [15:33:58] INFO Run start  [2/6]
# [15:33:58] INFO   id:                  k=5 rep=0 seed=123 bin=100000 track=counts gauss covs=gc-cpg tri=0
# [15:33:58] INFO   standardise:         per_chrom (on)
# [15:33:58] INFO   rf_seed:             10123
# [15:33:58] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0
# [15:33:58] INFO   celltypes:           mela, kera, fibr
# [15:33:58] INFO   chrom  1/24  elapsed=0.0s  rate=296.079 chr/s  eta=0.1s
# [15:35:23] INFO   chrom  5/24  elapsed=1m27.2s  rate=0.057 chr/s  eta=5m31.4s
# [15:36:47] INFO   chrom 10/24  elapsed=2m53.3s  rate=0.058 chr/s  eta=4m02.6s
# [15:37:55] INFO   chrom 15/24  elapsed=4m03.3s  rate=0.062 chr/s  eta=2m26.0s
# [15:38:51] INFO   chrom 20/24  elapsed=5m00.4s  rate=0.067 chr/s  eta=1m00.1s
# [15:39:35] INFO   chrom 24/24  elapsed=5m45.9s  rate=0.069 chr/s  eta=0.0s
# [15:39:46] INFO Run summary
# [15:39:46] INFO   bins_total:          30,970
# [15:39:46] INFO   mutations_total:     870,228
# [15:39:46] INFO   best (RF resid corr): mela  r=-0.2130  margin=0.0543
# [15:39:46] INFO   rf_r2_mean_weighted: 0.8273
# [15:39:46] INFO   ridge_r2_mean_weighted: 0.3438
# [15:39:46] INFO Outputs
# [15:39:46] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0/config.json
# [15:39:46] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0/chrom_summary.csv
# [15:39:46] INFO   per_bin:             skipped
# [15:39:46] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/results.csv
# [15:39:46] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0
# [15:39:46] INFO Run end k=5_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0 (356.9s)
# [15:39:46] INFO config bin=100000 track=inv_dist_gauss covs=gc-cpg
# [15:39:46] INFO Run start  [3/6]
# [15:39:46] INFO   id:                  k=5 rep=0 seed=123 bin=100000 track=inv dist gauss covs=gc-cpg tri=0
# [15:39:46] INFO   standardise:         per_chrom (on)
# [15:39:46] INFO   rf_seed:             10123
# [15:39:46] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0
# [15:39:46] INFO   celltypes:           mela, kera, fibr
# [15:39:46] INFO   chrom  1/24  elapsed=0.0s  rate=961.240 chr/s  eta=0.0s
# [15:41:02] INFO   chrom  5/24  elapsed=1m18.7s  rate=0.064 chr/s  eta=4m59.1s
# [15:42:30] INFO   chrom 10/24  elapsed=2m48.6s  rate=0.059 chr/s  eta=3m56.1s
# [15:43:52] INFO   chrom 15/24  elapsed=4m13.1s  rate=0.059 chr/s  eta=2m31.9s
# [15:45:05] INFO   chrom 20/24  elapsed=5m27.6s  rate=0.061 chr/s  eta=1m05.5s
# [15:45:55] INFO   chrom 24/24  elapsed=6m19.5s  rate=0.063 chr/s  eta=0.0s
# [15:46:07] INFO Run summary
# [15:46:07] INFO   bins_total:          30,970
# [15:46:07] INFO   mutations_total:     870,228
# [15:46:07] INFO   best (RF resid corr): mela  r=-0.0261  margin=0.0166
# [15:46:07] INFO   rf_r2_mean_weighted: 0.2921
# [15:46:07] INFO   ridge_r2_mean_weighted: 0.0267
# [15:46:07] INFO Outputs
# [15:46:07] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0/config.json
# [15:46:07] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0/chrom_summary.csv
# [15:46:07] INFO   per_bin:             skipped
# [15:46:07] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/results.csv
# [15:46:07] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=5_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0
# [15:46:07] INFO Run end k=5_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0 (391.5s)
# [15:46:07] INFO START Sample selection (k=10, rep=0, seed=123) ...
# [15:47:33] INFO DONE Sample selection (k=10, rep=0, seed=123) (1m28.4s)
# [15:47:33] INFO   selected_samples:    10
# [15:47:33] INFO   mutations_loaded:    1,008,569
# [15:47:33] INFO config bin=100000 track=counts_raw covs=gc-cpg
# [15:47:33] INFO Run start  [4/6]
# [15:47:33] INFO   id:                  k=10 rep=0 seed=123 bin=100000 track=counts raw covs=gc-cpg tri=0
# [15:47:33] INFO   standardise:         per_chrom (on)
# [15:47:33] INFO   rf_seed:             10123
# [15:47:33] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0
# [15:47:33] INFO   celltypes:           mela, kera, fibr
# [15:47:33] INFO   chrom  1/24  elapsed=0.0s  rate=671.824 chr/s  eta=0.0s
# [15:48:53] INFO   chrom  5/24  elapsed=1m21.4s  rate=0.061 chr/s  eta=5m09.3s
# [15:50:12] INFO   chrom 10/24  elapsed=2m43.5s  rate=0.061 chr/s  eta=3m48.9s
# [15:51:24] INFO   chrom 15/24  elapsed=3m56.8s  rate=0.063 chr/s  eta=2m22.1s
# [15:52:25] INFO   chrom 20/24  elapsed=4m59.8s  rate=0.067 chr/s  eta=60.0s
# [15:53:09] INFO   chrom 24/24  elapsed=5m45.4s  rate=0.069 chr/s  eta=0.0s
# [15:53:19] INFO Run summary
# [15:53:19] INFO   bins_total:          30,970
# [15:53:19] INFO   mutations_total:     1,008,569
# [15:53:19] INFO   best (RF resid corr): mela  r=-0.2331  margin=0.0574
# [15:53:19] INFO   rf_r2_mean_weighted: 0.8238
# [15:53:19] INFO   ridge_r2_mean_weighted: 0.3444
# [15:53:19] INFO Outputs
# [15:53:19] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0/config.json
# [15:53:19] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0/chrom_summary.csv
# [15:53:19] INFO   per_bin:             skipped
# [15:53:19] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/results.csv
# [15:53:19] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0
# [15:53:19] INFO Run end k=10_rep=0_seed=123_bin=100000_track=counts_raw_covs=gc-cpg_tri=0 (355.8s)
# [15:53:19] INFO config bin=100000 track=counts_gauss covs=gc-cpg
# [15:53:19] INFO Run start  [5/6]
# [15:53:19] INFO   id:                  k=10 rep=0 seed=123 bin=100000 track=counts gauss covs=gc-cpg tri=0
# [15:53:19] INFO   standardise:         per_chrom (on)
# [15:53:19] INFO   rf_seed:             10123
# [15:53:19] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0
# [15:53:19] INFO   celltypes:           mela, kera, fibr
# [15:53:19] INFO   chrom  1/24  elapsed=0.0s  rate=688.010 chr/s  eta=0.0s
# [15:54:37] INFO   chrom  5/24  elapsed=1m19.3s  rate=0.063 chr/s  eta=5m01.2s
# [15:55:58] INFO   chrom 10/24  elapsed=2m43.3s  rate=0.061 chr/s  eta=3m48.6s
# [15:57:09] INFO   chrom 15/24  elapsed=3m55.8s  rate=0.064 chr/s  eta=2m21.5s
# [15:58:08] INFO   chrom 20/24  elapsed=4m56.4s  rate=0.067 chr/s  eta=59.3s
# [15:58:53] INFO   chrom 24/24  elapsed=5m42.6s  rate=0.070 chr/s  eta=0.0s
# [15:59:03] INFO Run summary
# [15:59:03] INFO   bins_total:          30,970
# [15:59:03] INFO   mutations_total:     1,008,569
# [15:59:03] INFO   best (RF resid corr): mela  r=-0.2145  margin=0.0536
# [15:59:03] INFO   rf_r2_mean_weighted: 0.8371
# [15:59:03] INFO   ridge_r2_mean_weighted: 0.3503
# [15:59:03] INFO Outputs
# [15:59:03] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0/config.json
# [15:59:03] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0/chrom_summary.csv
# [15:59:03] INFO   per_bin:             skipped
# [15:59:03] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/results.csv
# [15:59:03] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0
# [15:59:03] INFO Run end k=10_rep=0_seed=123_bin=100000_track=counts_gauss_covs=gc-cpg_tri=0 (353.1s)
# [15:59:03] INFO config bin=100000 track=inv_dist_gauss covs=gc-cpg
# [15:59:03] INFO Run start  [6/6]
# [15:59:03] INFO   id:                  k=10 rep=0 seed=123 bin=100000 track=inv dist gauss covs=gc-cpg tri=0
# [15:59:03] INFO   standardise:         per_chrom (on)
# [15:59:03] INFO   rf_seed:             10123
# [15:59:03] INFO   out_dir:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0
# [15:59:03] INFO   celltypes:           mela, kera, fibr
# [15:59:03] INFO   chrom  1/24  elapsed=0.0s  rate=722.180 chr/s  eta=0.0s
# [16:00:26] INFO   chrom  5/24  elapsed=1m24.6s  rate=0.059 chr/s  eta=5m21.3s
# [16:01:44] INFO   chrom 10/24  elapsed=2m45.9s  rate=0.060 chr/s  eta=3m52.2s
# [16:02:58] INFO   chrom 15/24  elapsed=4m01.1s  rate=0.062 chr/s  eta=2m24.7s
# [16:03:59] INFO   chrom 20/24  elapsed=5m04.0s  rate=0.066 chr/s  eta=1m00.8s
# [16:04:42] INFO   chrom 24/24  elapsed=5m48.5s  rate=0.069 chr/s  eta=0.0s
# [16:04:52] INFO Run summary
# [16:04:52] INFO   bins_total:          30,970
# [16:04:52] INFO   mutations_total:     1,008,569
# [16:04:52] INFO   best (RF resid corr): mela  r=-0.0307  margin=0.0135
# [16:04:52] INFO   rf_r2_mean_weighted: 0.3021
# [16:04:52] INFO   ridge_r2_mean_weighted: 0.0216
# [16:04:52] INFO Outputs
# [16:04:52] INFO   config:              /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0/config.json
# [16:04:52] INFO   chrom_sum:           /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0/chrom_summary.csv
# [16:04:52] INFO   per_bin:             skipped
# [16:04:52] INFO   results:             /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/results.csv
# [16:04:52] INFO saved run outputs /home/lem/projects/mut-epi-origin/outputs/experiments/mut_vs_dnase_quickcheck_v2/runs/k=10_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0
# [16:04:52] INFO Run end k=10_rep=0_seed=123_bin=100000_track=inv_dist_gauss_covs=gc-cpg_tri=0 (359.1s)
#    sample_size_k  repeat  seed_samples  n_selected_samples  bin_size  \
# 3             10       0           123                  10    100000
# 0              5       0           123                   5    100000
# 4             10       0           123                  10    100000
# 1              5       0           123                   5    100000
# 5             10       0           123                  10    100000
# 2              5       0           123                   5    100000
#
#    track_strategy covariates  include_trinuc  n_mutations_total  n_bins_total  \
# 3      counts_raw     gc,cpg           False            1008569         30970
# 0      counts_raw     gc,cpg           False             870228         30970
# 4    counts_gauss     gc,cpg           False            1008569         30970
# 1    counts_gauss     gc,cpg           False             870228         30970
# 5  inv_dist_gauss     gc,cpg           False            1008569         30970
# 2  inv_dist_gauss     gc,cpg           False             870228         30970
#
#    ... best_celltype_rf_resid  best_celltype_rf_resid_value  \
# 3  ...                   mela                     -0.233096
# 0  ...                   mela                     -0.230388
# 4  ...                   mela                     -0.214528
# 1  ...                   mela                     -0.212951
# 5  ...                   mela                     -0.030705
# 2  ...                   mela                     -0.026054
#
#    best_minus_second_rf_resid  \
# 3                    0.057424
# 0                    0.058487
# 4                    0.053593
# 1                    0.054282
# 5                    0.013528
# 2                    0.016609
#
#                        rf_perm_importances_mean_json  \
# 3  {"gc_fraction": 0.17750303469211554, "cpg_per_...
# 0  {"gc_fraction": 0.19426387385245789, "cpg_per_...
# 4  {"gc_fraction": 0.14487722686724722, "cpg_per_...
# 1  {"gc_fraction": 0.15329233966385913, "cpg_per_...
# 5  {"gc_fraction": 0.1329228668692673, "cpg_per_b...
# 2  {"gc_fraction": 0.12383635708320713, "cpg_per_...
#
#                       rf_feature_sign_corr_mean_json  \
# 3  {"gc_fraction": 0.09959670794484987, "cpg_per_...
# 0  {"gc_fraction": 0.10256830998131991, "cpg_per_...
# 4  {"gc_fraction": 0.09464089381011018, "cpg_per_...
# 1  {"gc_fraction": 0.09798324089813859, "cpg_per_...
# 5  {"gc_fraction": 0.035882963699299136, "cpg_per...
# 2  {"gc_fraction": 0.03465911096606451, "cpg_per_...
#
#                                 ridge_coef_mean_json  rf_r2_mean_weighted  \
# 3  {"gc_fraction": 0.624586684007952, "cpg_per_bp...             0.823762
# 0  {"gc_fraction": 0.6144617307134598, "cpg_per_b...             0.810761
# 4  {"gc_fraction": 0.6274325378326392, "cpg_per_b...             0.837097
# 1  {"gc_fraction": 0.6184543923161678, "cpg_per_b...             0.827340
# 5  {"gc_fraction": 0.11321118164809708, "cpg_per_...             0.302134
# 2  {"gc_fraction": 0.10405105268791624, "cpg_per_...             0.292115
#
#    ridge_r2_mean_weighted  rf_top_celltype_feature_perm  \
# 3                0.344438                          mela
# 0                0.335927                          mela
# 4                0.350256                          mela
# 1                0.343755                          mela
# 5                0.021581                          fibr
# 2                0.026742                          fibr
#
#    rf_top_celltype_importance_perm
# 3                         0.952435
# 0                         0.949471
# 4                         0.920506
# 1                         0.919171
# 5                         0.204620
# 2                         0.231002
#
# [6 rows x 45 columns]

# %%
from scripts.pipeline_mut_vs_accessibility import run_grid_experiment

# Full grid search
results = run_grid_experiment(
    mut_path=MUT_PATH,
    fai_path=FAI_PATH,
    fasta_path=FASTA_PATH,
    dnase_bigwigs=DNASE_MAP,
    timing_bigwig=TIMING_BW,
    sample_sizes=[5, 10, 20],
    repeats=1,
    base_seed=123,
    bin_sizes=[50_000, 100_000],
    track_strategies=["counts_raw", "counts_gauss", "inv_dist_gauss"],
    covariate_sets=[
        ["gc", "cpg"],
        ["gc", "cpg", "timing"],
    ],
    include_trinuc=False,
    chroms=None,  # all chromosomes in the .fai
    standardise_tracks=True,
    standardise_scope="per_chrom",
    verbose=True,
    out_dir=PROJECT_ROOT / "outputs" / "experiments" / "mut_vs_dnase_multi_v1",
    tumour_whitelist=TUMOUR_WHITELIST,
    save_per_bin=True,
)

results.sort_values("best_celltype_linear_resid_value").head(10)
