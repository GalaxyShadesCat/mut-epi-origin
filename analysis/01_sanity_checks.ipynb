# %%
import sys
from pathlib import Path

# Resolve project root (notebook is in analysis/)
PROJECT_ROOT = Path.cwd().resolve().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# Define data paths
MUT_PATH = [
    PROJECT_ROOT / "data" / "raw" / "mutations" / "UV_mutations.bed",
    PROJECT_ROOT / "data" / "raw" / "mutations" / "ICGC_WGS_Feb20_mutations.bed"
]
FAI_PATH = PROJECT_ROOT / "data" / "raw" / "reference" / "GRCh37.fa.fai"
FASTA_PATH = PROJECT_ROOT / "data" / "raw" / "reference" / "GRCh37.fa"
TIMING_BW = PROJECT_ROOT / "data" / "raw" / "timing" / "repliSeq_SknshWaveSignalRep1.bigWig"

DNASE_MAP = {
    "mela": PROJECT_ROOT / "data" / "raw" / "DNase-seq" / "mela_ENCFF285GEW.bigWig",
    "kera": PROJECT_ROOT / "data" / "raw" / "DNase-seq" / "kera_ENCFF597YXQ.bigWig",
    "fibr": PROJECT_ROOT / "data" / "raw" / "DNase-seq" / "fibr_ENCFF355OPU.bigWig",
}

# %%
from scripts.sanity_checks import SanityConfig, run_all_sanity_checks

cfg = SanityConfig(
    project_root=PROJECT_ROOT,
    mut_path=MUT_PATH,
    fai_path=FAI_PATH,
    fasta_path=FASTA_PATH,
    dnase_bws=DNASE_MAP,
    timing_bw=TIMING_BW,
    k_samples=1,
    seed=123,
    bin_size=50_000,
    check_chrom="chr1",
    tumour_whitelist=None,
    hard_fail=False,
)

run_all_sanity_checks(cfg)
# Out:
# === SANITY CHECKS BEGIN ===
# PROJECT_ROOT: /home/lem/projects/mut-epi-origin
# mut_path(s):
#   - /home/lem/projects/mut-epi-origin/data/raw/mutations/UV_mutations.bed
#   - /home/lem/projects/mut-epi-origin/data/raw/mutations/ICGC_WGS_Feb20_mutations.bed
# fai_path:     /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa.fai
# fasta_path:   /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa
# dnase_bws:
#   - mela: /home/lem/projects/mut-epi-origin/data/raw/DNase-seq/mela_ENCFF285GEW.bigWig
#   - kera: /home/lem/projects/mut-epi-origin/data/raw/DNase-seq/kera_ENCFF597YXQ.bigWig
#   - fibr: /home/lem/projects/mut-epi-origin/data/raw/DNase-seq/fibr_ENCFF355OPU.bigWig
# timing_bw:    /home/lem/projects/mut-epi-origin/data/raw/timing/repliSeq_SknshWaveSignalRep1.bigWig
# k=1, seed=123, bin_size=50000, check_chrom=chr1
#
# [PASS] check_chrom uses internal canonical chr-style (chr1)
# [PASS] pysam import OK
# [PASS] pyBigWig import OK
# [PASS] PROJECT_ROOT exists
# [PASS] mut_path provided
# [PASS] mut_path exists: /home/lem/projects/mut-epi-origin/data/raw/mutations/UV_mutations.bed
# [PASS] mut_path exists: /home/lem/projects/mut-epi-origin/data/raw/mutations/ICGC_WGS_Feb20_mutations.bed
# [PASS] fai_path exists: /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa.fai
# [PASS] fasta_path exists: /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa
# [PASS] dnase_bws provided
# [PASS] DNase bigWig exists [mela]: /home/lem/projects/mut-epi-origin/data/raw/DNase-seq/mela_ENCFF285GEW.bigWig
# [PASS] DNase bigWig exists [kera]: /home/lem/projects/mut-epi-origin/data/raw/DNase-seq/kera_ENCFF597YXQ.bigWig
# [PASS] DNase bigWig exists [fibr]: /home/lem/projects/mut-epi-origin/data/raw/DNase-seq/fibr_ENCFF355OPU.bigWig
# [PASS] timing_bw exists: /home/lem/projects/mut-epi-origin/data/raw/timing/repliSeq_SknshWaveSignalRep1.bigWig
# [PASS] FASTA index exists: /home/lem/projects/mut-epi-origin/data/raw/reference/GRCh37.fa.fai
# [PASS] FAI loaded with rows
# [PASS] iter_chroms() returned 24 primary contigs
# [PASS] Primary contig list exactly chr1..chr22,chrX,chrY (internal standard)
# [PASS] FAI contig naming style looks like: numeric (this can differ from internal canonical)
# [PASS] chr1 is resolvable in FAI (maps to '1')
# [PASS] [DNase:mela] bigWig contig naming style looks like: chr*
# [PASS] [DNase:mela] bigWig can resolve chr1 (maps to 'chr1')
# [PASS] [DNase:mela] bigWig contains/resolves most primary chroms (24/24)
# [PASS] [DNase:kera] bigWig contig naming style looks like: chr*
# [PASS] [DNase:kera] bigWig can resolve chr1 (maps to 'chr1')
# [PASS] [DNase:kera] bigWig contains/resolves most primary chroms (24/24)
# [PASS] [DNase:fibr] bigWig contig naming style looks like: chr*
# [PASS] [DNase:fibr] bigWig can resolve chr1 (maps to 'chr1')
# [PASS] [DNase:fibr] bigWig contains/resolves most primary chroms (24/24)
# [PASS] [Timing] bigWig contig naming style looks like: chr*
# [PASS] [Timing] bigWig can resolve chr1 (maps to 'chr1')
# [PASS] [Timing] bigWig contains/resolves most primary chroms (23/24)
# [PASS] [UV_mutations.bed] mutation file has content
# [PASS] [UV_mutations.bed] tab-delimited with >= 6 columns (OK)
# [PASS] [ICGC_WGS_Feb20_mutations.bed] mutation file has content
# [PASS] [ICGC_WGS_Feb20_mutations.bed] tab-delimited with >= 6 columns (OK)
# [PASS] Selected k=1 sample keys
# [PASS] muts_df has rows for selected sample(s)
# [PASS] muts_df has expected columns
# [PASS] All mutation Chromosome values are chr*-style (internal standard OK)
# [PASS] All Start values parse as integers
# [PASS] All End values parse as integers
# [PASS] All Start < End (BED-style)
# [PASS] muts_df contains exactly k unique Sample_IDs (1)
# [PASS] muts_df rows: 38,307. Top chroms:
# Chromosome
# chr2    3870
# chr6    3472
# chr4    3280
# chr3    3109
# chr7    2904
# Name: count, dtype: int64
# [PASS] chr1 resolves in FAI (maps to '1')
# [PASS] chr1 length looks plausible (249,250,621) [FAI contig '1']
# [PASS] Bin edges and centres consistent
# [PASS] Bins start at 0
# [PASS] Bins cover chromosome length
# [PASS] Built 4,986 bins for chr1 at bin_size=50,000
# [PASS] Selected sample(s) have mutations on chr1
# [PASS] Mutation starts are >= 0
# [PASS] chr1: n_mutations=2,425, start range [1,128,531, 248,877,585]
# [PASS] [DNase:mela] track length equals n_bins
# [PASS] [DNase:mela] has some finite values
# [PASS] [DNase:mela] mostly finite (4986/4986)
# [PASS] [DNase:mela] stats: finite=4986/4986, min=0, max=4.61
# [PASS] [DNase:kera] track length equals n_bins
# [PASS] [DNase:kera] has some finite values
# [PASS] [DNase:kera] mostly finite (4986/4986)
# [PASS] [DNase:kera] stats: finite=4986/4986, min=0, max=3.48
# [PASS] [DNase:fibr] track length equals n_bins
# [PASS] [DNase:fibr] has some finite values
# [PASS] [DNase:fibr] mostly finite (4986/4986)
# [PASS] [DNase:fibr] stats: finite=4986/4986, min=0, max=3.91
# [PASS] [Timing] track length equals n_bins
# [PASS] [Timing] has some finite values
# [PASS] [Timing] stats: finite=4985/4986, min=-2.57, max=77.1
# [PASS] GC covariate length equals n_bins
# [PASS] CpG covariate length equals n_bins
# [PASS] GC has some finite values
# [PASS] CpG has some finite values
# [PASS] GC fraction within [0,1] (min=0.000, max=0.647)
# [PASS] CpG stats: finite=4986/4986, min=0, max=0.063
#
# === SANITY CHECKS END ===

# %%
from pathlib import Path
import pandas as pd

icgc_path = Path("/home/lem/projects/mut-epi-origin/data/raw/mutations/ICGC_WGS_Feb20_mutations.bed")

# Column 6 (0-based) = Project / cohort label (e.g. BRCA-UK)
projects = set()

for chunk in pd.read_csv(
    icgc_path,
    sep="\t",
    header=None,
    usecols=[6],
    names=["Project"],
    dtype=str,
    chunksize=500_000,
    low_memory=False,
):
    s = chunk["Project"].fillna("").astype(str).str.strip()
    s = s[s != ""]
    projects.update(s.tolist())

projects = sorted(projects)
print(f"n_projects={len(projects)}")
print("\n".join(projects))
# Out:
# n_projects=68
# ALL-US
# AML-US
# BLCA-US
# BOCA-FR
# BOCA-UK
# BRCA-EU
# BRCA-FR
# BRCA-UK
# BRCA-US
# BTCA-SG
# CESC-US
# CLLE-ES
# CMDI-UK
# COAD-US
# COCA-CN
# DLBC-US
# EOPC-DE
# ESAD-UK
# ESCA-CN
# GACA-CN
# GBM-US
# HNSC-US
# KICH-US
# KIRC-US
# KIRP-US
# LAML-KR
# LGG-US
# LIAD-FR
# LICA-CN
# LICA-FR
# LIHC-US
# LINC-JP
# LIRI-JP
# LMS-FR
# LUAD-US
# LUSC-CN
# LUSC-KR
# LUSC-US
# MALY-DE
# MELA-AU
# NBL-US
# NKTL-SG
# ORCA-IN
# OV-AU
# OV-US
# PACA-AU
# PACA-CA
# PAEN-AU
# PAEN-IT
# PBCA-DE
# PBCA-US
# PEME-CA
# PRAD-CA
# PRAD-CN
# PRAD-FR
# PRAD-UK
# PRAD-US
# READ-US
# RECA-EU
# RT-US
# SARC-US
# SKCA-BR
# SKCM-US
# STAD-US
# THCA-US
# UCEC-US
# UTCA-FR
# WT-US
